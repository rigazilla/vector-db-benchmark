# %% [markdown]
# ### Notebook to process benchmar results
#
# Please run this notebook after running all the benchmarks and storing them in the `results` dir. This will export them in the desired format for the single node benchmark plots of [qdrant.tech/benchmarks](https://qdrant.tech/benchmarks)

# %%
from pathlib import Path
import re
import json
import pandas as pd
from datetime import datetime, timezone

# %%
DATA_DIR = Path().resolve().parent / "results"
DATA_DIR, list(DATA_DIR.glob("*.json"))[0].name
# Out:
# (PosixPath('/home/rigazilla/git/vector-db-benchmark/results'),
#  'redis-m-32-ef-128-gist-960-euclidean-upload-2024-03-18-18-57-07.json')

# %%
PATH_REGEX = re.compile(r"(?P<engine_name>("
                        r"?P<engine>[a-z\-]+)"
                        r"\-m\-(?P<m>[0-9]+)"
                        r"\-ef\-(?P<ef>[0-9]+)"
                        r")"
                        r"\-(?P<dataset>[a-zA-Z0-9\-]+)"
                        r"\-(?P<operation>(search)|(upload))"
                        r"(\-(?P<search_index>[0-9]{1,2})\-)?"
                        r"\-?(?P<date>.*)\.json")

# %%
upload_results, search_results = [], []

for path in DATA_DIR.glob("*.json"):
    match = PATH_REGEX.match(path.name)
    if match is None:
        continue
        
    experiment = match.groupdict()
    
    with open(path, "r") as fp:
        stats = json.load(fp)

    entry = [match["engine"], match["m"], match["ef"], 
             match["dataset"], match["search_index"], match["date"], 
             stats["params"], stats["results"]]
    if experiment["operation"] == "search":
        search_results.append(entry)
    elif experiment["operation"] == "upload":
        upload_results.append(entry)

len(upload_results), len(search_results)
# Out:
# (2, 16)

# %%
column_names = ["engine", "m", "ef", "dataset", "search_index", "date", "params", "results"]

# %%
upload_df = pd.DataFrame(upload_results, columns=column_names) \
    .drop(columns="search_index")
upload_df["date"] = pd.to_datetime(upload_df["date"], format="%Y-%m-%d-%H-%M-%S")
upload_df = upload_df.sort_values("date", ascending=False) \
    .groupby(["engine", "m", "ef", "dataset"]) \
    .last()
upload_df = pd.concat([upload_df, upload_df["results"].apply(pd.Series)], axis=1)
upload_df = upload_df.drop(columns="results")

print(len(upload_df))

upload_df.sort_values("total_time", ascending=True).head(n=5)
# Out:
# 2
#                                                     date  \
# engine     m  ef  dataset
# redis      32 128 gist-960-euclidean 2024-03-18 18:57:07
# infinispan 32 128 gist-960-euclidean 2024-03-19 15:55:13
#
#                                                                                  params  \
# engine     m  ef  dataset
# redis      32 128 gist-960-euclidean  {'experiment': 'redis-m-32-ef-128', 'engine': ...
# infinispan 32 128 gist-960-euclidean  {'experiment': 'infinispan-m-32-ef-128', 'engi...
#
#                                      post_upload  upload_time   total_time
# engine     m  ef  dataset
# redis      32 128 gist-960-euclidean          {}  1968.103895  1968.103937
# infinispan 32 128 gist-960-euclidean          {}  4692.670652  4692.670674

# %%
search_df = pd.DataFrame(search_results, columns=column_names)
search_df["date"] = pd.to_datetime(search_df["date"], format="%Y-%m-%d-%H-%M-%S")
search_df = search_df.sort_values("date", ascending=False) \
    .groupby(["engine", "m", "ef", "dataset", "search_index"]) \
    .first()

print(len(search_df))

for column_name in ["params", "results","date", "dataset", "engine"]:
    search_df = pd.concat([search_df, search_df[column_name].apply(pd.Series)], axis=1)
    search_df = search_df.drop(columns=column_name)
search_df.sort_values("rps", ascending=False).head(n=16)
# Out:
# 16
#                                                                experiment  \
# engine     m  ef  dataset            search_index
# redis      32 128 gist-960-euclidean 4                  redis-m-32-ef-128
#                                      5                  redis-m-32-ef-128
#                                      0                  redis-m-32-ef-128
#                                      1                  redis-m-32-ef-128
#                                      6                  redis-m-32-ef-128
#                                      2                  redis-m-32-ef-128
#                                      7                  redis-m-32-ef-128
#                                      3                  redis-m-32-ef-128
# infinispan 32 128 gist-960-euclidean 5             infinispan-m-32-ef-128
#                                      6             infinispan-m-32-ef-128
#                                      4             infinispan-m-32-ef-128
#                                      7             infinispan-m-32-ef-128
#                                      3             infinispan-m-32-ef-128
#                                      1             infinispan-m-32-ef-128
#                                      2             infinispan-m-32-ef-128
#                                      0             infinispan-m-32-ef-128
#
#                                                    parallel search_params  \
# engine     m  ef  dataset            search_index
# redis      32 128 gist-960-euclidean 4                  100    {'ef': 64}
#                                      5                  100   {'ef': 128}
#                                      0                    1    {'ef': 64}
#                                      1                    1   {'ef': 128}
#                                      6                  100   {'ef': 256}
#                                      2                    1   {'ef': 256}
#                                      7                  100   {'ef': 512}
#                                      3                    1   {'ef': 512}
# infinispan 32 128 gist-960-euclidean 5                  100   {'ef': 128}
#                                      6                  100   {'ef': 256}
#                                      4                  100    {'ef': 64}
#                                      7                  100   {'ef': 512}
#                                      3                    1   {'ef': 512}
#                                      1                    1   {'ef': 128}
#                                      2                    1   {'ef': 256}
#                                      0                    1    {'ef': 64}
#
#                                                    total_time  mean_time  \
# engine     m  ef  dataset            search_index
# redis      32 128 gist-960-euclidean 4               2.047130   0.183394
#                                      5               2.426658   0.220274
#                                      0               3.134228   0.003046
#                                      1               3.434508   0.003345
#                                      6               3.893497   0.363886
#                                      2               5.077234   0.004971
#                                      7               6.497608   0.618295
#                                      3               8.099951   0.007972
# infinispan 32 128 gist-960-euclidean 5              10.475890   1.007671
#                                      6              13.086889   1.250723
#                                      4              14.121041   1.353599
#                                      7              15.118512   1.449361
#                                      3              63.704724   0.063441
#                                      1              63.955368   0.063692
#                                      2              65.581345   0.065305
#                                      0              79.762096   0.079463
#
#                                                    mean_precisions  std_time  \
# engine     m  ef  dataset            search_index
# redis      32 128 gist-960-euclidean 4                     0.75632  0.057327
#                                      5                     0.79936  0.050495
#                                      0                     0.75632  0.000373
#                                      1                     0.79936  0.000437
#                                      6                     0.89231  0.068511
#                                      2                     0.89231  0.000825
#                                      7                     0.94885  0.086542
#                                      3                     0.94885  0.005054
# infinispan 32 128 gist-960-euclidean 5                     0.10000  0.432922
#                                      6                     0.10000  0.526012
#                                      4                     0.10000  0.599905
#                                      7                     0.10000  0.446774
#                                      3                     0.10000  0.009431
#                                      1                     0.10000  0.009241
#                                      2                     0.10000  0.011458
#                                      0                     0.10000  0.082147
#
#                                                    min_time  max_time  \
# engine     m  ef  dataset            search_index
# redis      32 128 gist-960-euclidean 4             0.013735  0.384822
#                                      5             0.011361  0.413207
#                                      0             0.001923  0.005209
#                                      1             0.002062  0.004802
#                                      6             0.013783  0.654896
#                                      2             0.002479  0.007400
#                                      7             0.018249  0.736370
#                                      3             0.003178  0.160063
# infinispan 32 128 gist-960-euclidean 5             0.091883  3.241671
#                                      6             0.112938  2.976911
#                                      4             0.136803  3.070009
#                                      7             0.284828  2.733841
#                                      3             0.025886  0.125589
#                                      1             0.025792  0.127611
#                                      2             0.025409  0.143860
#                                      0             0.036065  2.624805
#
#                                                           rps  p95_time  \
# engine     m  ef  dataset            search_index
# redis      32 128 gist-960-euclidean 4             488.488837  0.291484
#                                      5             412.089469  0.256568
#                                      0             319.057856  0.003583
#                                      1             291.162509  0.003982
#                                      6             256.838509  0.419571
#                                      2             196.957632  0.006126
#                                      7             153.902783  0.706901
#                                      3             123.457534  0.009996
# infinispan 32 128 gist-960-euclidean 5              95.457288  1.690915
#                                      6              76.412353  2.117653
#                                      4              70.816308  2.304622
#                                      7              66.144076  2.145022
#                                      3              15.697423  0.073783
#                                      1              15.635904  0.073856
#                                      2              15.248239  0.080550
#                                      0              12.537283  0.096770
#
#                                                    p99_time  \
# engine     m  ef  dataset            search_index
# redis      32 128 gist-960-euclidean 4             0.379020
#                                      5             0.402430
#                                      0             0.003778
#                                      1             0.004193
#                                      6             0.644122
#                                      2             0.006502
#                                      7             0.731007
#                                      3             0.011500
# infinispan 32 128 gist-960-euclidean 5             1.958981
#                                      6             2.452173
#                                      4             2.616821
#                                      7             2.455565
#                                      3             0.077441
#                                      1             0.077532
#                                      2             0.093705
#                                      0             0.115982
#
#                                                                     0  \
# engine     m  ef  dataset            search_index
# redis      32 128 gist-960-euclidean 4            2024-03-18 18:57:44
#                                      5            2024-03-18 18:58:02
#                                      0            2024-03-18 18:57:10
#                                      1            2024-03-18 18:57:13
#                                      6            2024-03-18 18:58:21
#                                      2            2024-03-18 18:57:18
#                                      7            2024-03-18 18:58:43
#                                      3            2024-03-18 18:57:26
# infinispan 32 128 gist-960-euclidean 5            2024-03-19 16:00:42
#                                      6            2024-03-19 16:01:11
#                                      4            2024-03-19 16:00:16
#                                      7            2024-03-19 16:01:42
#                                      3            2024-03-19 15:59:46
#                                      1            2024-03-19 15:57:37
#                                      2            2024-03-19 15:58:43
#                                      0            2024-03-19 15:56:33
#
#                                                                     0  \
# engine     m  ef  dataset            search_index
# redis      32 128 gist-960-euclidean 4             gist-960-euclidean
#                                      5             gist-960-euclidean
#                                      0             gist-960-euclidean
#                                      1             gist-960-euclidean
#                                      6             gist-960-euclidean
#                                      2             gist-960-euclidean
#                                      7             gist-960-euclidean
#                                      3             gist-960-euclidean
# infinispan 32 128 gist-960-euclidean 5             gist-960-euclidean
#                                      6             gist-960-euclidean
#                                      4             gist-960-euclidean
#                                      7             gist-960-euclidean
#                                      3             gist-960-euclidean
#                                      1             gist-960-euclidean
#                                      2             gist-960-euclidean
#                                      0             gist-960-euclidean
#
#                                                             0
# engine     m  ef  dataset            search_index
# redis      32 128 gist-960-euclidean 4                  redis
#                                      5                  redis
#                                      0                  redis
#                                      1                  redis
#                                      6                  redis
#                                      2                  redis
#                                      7                  redis
#                                      3                  redis
# infinispan 32 128 gist-960-euclidean 5             infinispan
#                                      6             infinispan
#                                      4             infinispan
#                                      7             infinispan
#                                      3             infinispan
#                                      1             infinispan
#                                      2             infinispan
#                                      0             infinispan

# %%
_search = search_df.reset_index()
_upload = upload_df.reset_index()

joined_df = _search.merge(_upload, on=["engine", "m", "ef", "dataset"], how="left", suffixes=("_search", "_upload"))
print(len(joined_df))
joined_df
# Out:
# 16
#         engine   m   ef             dataset search_index  \
# 0   infinispan  32  128  gist-960-euclidean            0
# 1   infinispan  32  128  gist-960-euclidean            1
# 2   infinispan  32  128  gist-960-euclidean            2
# 3   infinispan  32  128  gist-960-euclidean            3
# 4   infinispan  32  128  gist-960-euclidean            4
# 5   infinispan  32  128  gist-960-euclidean            5
# 6   infinispan  32  128  gist-960-euclidean            6
# 7   infinispan  32  128  gist-960-euclidean            7
# 8        redis  32  128  gist-960-euclidean            0
# 9        redis  32  128  gist-960-euclidean            1
# 10       redis  32  128  gist-960-euclidean            2
# 11       redis  32  128  gist-960-euclidean            3
# 12       redis  32  128  gist-960-euclidean            4
# 13       redis  32  128  gist-960-euclidean            5
# 14       redis  32  128  gist-960-euclidean            6
# 15       redis  32  128  gist-960-euclidean            7
#
#                 experiment  parallel search_params  total_time_search  \
# 0   infinispan-m-32-ef-128         1    {'ef': 64}          79.762096
# 1   infinispan-m-32-ef-128         1   {'ef': 128}          63.955368
# 2   infinispan-m-32-ef-128         1   {'ef': 256}          65.581345
# 3   infinispan-m-32-ef-128         1   {'ef': 512}          63.704724
# 4   infinispan-m-32-ef-128       100    {'ef': 64}          14.121041
# 5   infinispan-m-32-ef-128       100   {'ef': 128}          10.475890
# 6   infinispan-m-32-ef-128       100   {'ef': 256}          13.086889
# 7   infinispan-m-32-ef-128       100   {'ef': 512}          15.118512
# 8        redis-m-32-ef-128         1    {'ef': 64}           3.134228
# 9        redis-m-32-ef-128         1   {'ef': 128}           3.434508
# 10       redis-m-32-ef-128         1   {'ef': 256}           5.077234
# 11       redis-m-32-ef-128         1   {'ef': 512}           8.099951
# 12       redis-m-32-ef-128       100    {'ef': 64}           2.047130
# 13       redis-m-32-ef-128       100   {'ef': 128}           2.426658
# 14       redis-m-32-ef-128       100   {'ef': 256}           3.893497
# 15       redis-m-32-ef-128       100   {'ef': 512}           6.497608
#
#     mean_time  ...  p95_time  p99_time                   0  \
# 0    0.079463  ...  0.096770  0.115982 2024-03-19 15:56:33
# 1    0.063692  ...  0.073856  0.077532 2024-03-19 15:57:37
# 2    0.065305  ...  0.080550  0.093705 2024-03-19 15:58:43
# 3    0.063441  ...  0.073783  0.077441 2024-03-19 15:59:46
# 4    1.353599  ...  2.304622  2.616821 2024-03-19 16:00:16
# 5    1.007671  ...  1.690915  1.958981 2024-03-19 16:00:42
# 6    1.250723  ...  2.117653  2.452173 2024-03-19 16:01:11
# 7    1.449361  ...  2.145022  2.455565 2024-03-19 16:01:42
# 8    0.003046  ...  0.003583  0.003778 2024-03-18 18:57:10
# 9    0.003345  ...  0.003982  0.004193 2024-03-18 18:57:13
# 10   0.004971  ...  0.006126  0.006502 2024-03-18 18:57:18
# 11   0.007972  ...  0.009996  0.011500 2024-03-18 18:57:26
# 12   0.183394  ...  0.291484  0.379020 2024-03-18 18:57:44
# 13   0.220274  ...  0.256568  0.402430 2024-03-18 18:58:02
# 14   0.363886  ...  0.419571  0.644122 2024-03-18 18:58:21
# 15   0.618295  ...  0.706901  0.731007 2024-03-18 18:58:43
#
#                      0           0                date  \
# 0   gist-960-euclidean  infinispan 2024-03-19 15:55:13
# 1   gist-960-euclidean  infinispan 2024-03-19 15:55:13
# 2   gist-960-euclidean  infinispan 2024-03-19 15:55:13
# 3   gist-960-euclidean  infinispan 2024-03-19 15:55:13
# 4   gist-960-euclidean  infinispan 2024-03-19 15:55:13
# 5   gist-960-euclidean  infinispan 2024-03-19 15:55:13
# 6   gist-960-euclidean  infinispan 2024-03-19 15:55:13
# 7   gist-960-euclidean  infinispan 2024-03-19 15:55:13
# 8   gist-960-euclidean       redis 2024-03-18 18:57:07
# 9   gist-960-euclidean       redis 2024-03-18 18:57:07
# 10  gist-960-euclidean       redis 2024-03-18 18:57:07
# 11  gist-960-euclidean       redis 2024-03-18 18:57:07
# 12  gist-960-euclidean       redis 2024-03-18 18:57:07
# 13  gist-960-euclidean       redis 2024-03-18 18:57:07
# 14  gist-960-euclidean       redis 2024-03-18 18:57:07
# 15  gist-960-euclidean       redis 2024-03-18 18:57:07
#
#                                                params post_upload  \
# 0   {'experiment': 'infinispan-m-32-ef-128', 'engi...          {}
# 1   {'experiment': 'infinispan-m-32-ef-128', 'engi...          {}
# 2   {'experiment': 'infinispan-m-32-ef-128', 'engi...          {}
# 3   {'experiment': 'infinispan-m-32-ef-128', 'engi...          {}
# 4   {'experiment': 'infinispan-m-32-ef-128', 'engi...          {}
# 5   {'experiment': 'infinispan-m-32-ef-128', 'engi...          {}
# 6   {'experiment': 'infinispan-m-32-ef-128', 'engi...          {}
# 7   {'experiment': 'infinispan-m-32-ef-128', 'engi...          {}
# 8   {'experiment': 'redis-m-32-ef-128', 'engine': ...          {}
# 9   {'experiment': 'redis-m-32-ef-128', 'engine': ...          {}
# 10  {'experiment': 'redis-m-32-ef-128', 'engine': ...          {}
# 11  {'experiment': 'redis-m-32-ef-128', 'engine': ...          {}
# 12  {'experiment': 'redis-m-32-ef-128', 'engine': ...          {}
# 13  {'experiment': 'redis-m-32-ef-128', 'engine': ...          {}
# 14  {'experiment': 'redis-m-32-ef-128', 'engine': ...          {}
# 15  {'experiment': 'redis-m-32-ef-128', 'engine': ...          {}
#
#     upload_time total_time_upload
# 0   4692.670652       4692.670674
# 1   4692.670652       4692.670674
# 2   4692.670652       4692.670674
# 3   4692.670652       4692.670674
# 4   4692.670652       4692.670674
# 5   4692.670652       4692.670674
# 6   4692.670652       4692.670674
# 7   4692.670652       4692.670674
# 8   1968.103895       1968.103937
# 9   1968.103895       1968.103937
# 10  1968.103895       1968.103937
# 11  1968.103895       1968.103937
# 12  1968.103895       1968.103937
# 13  1968.103895       1968.103937
# 14  1968.103895       1968.103937
# 15  1968.103895       1968.103937
#
# [16 rows x 25 columns]

# %%
json_all = []
json_1_or_100_thread = []

for index, row in joined_df.reset_index().iterrows():
    engine_params = {}
    if isinstance(row['search_params'], dict):
        engine_params.update(row['search_params'])
    if isinstance(row['params'], dict):
        engine_params.update(row['params'])

    engine_name = row['engine']

    if engine_name == "qdrant-rps" or engine_name == "qdrant-bq-rps" or engine_name == "qdrant-sq-rps":
        engine_name = "qdrant"

    json_object = {
        "engine_name": engine_name,
        "setup_name": f"{row['engine']}-m-{row['m']}-ef-{row['ef']}",
        "dataset_name": row['dataset'],
        # "search_idx": row['search_index'],
        "upload_time": row['upload_time'],
        "total_upload_time": row['total_time_upload'],
        "p95_time": row['p95_time'],
        "rps": row['rps'],
        "parallel": row['parallel'],
        "p99_time": row['p99_time'],
        "mean_time": row['mean_time'],
        "mean_precisions": row['mean_precisions'],
        "engine_params": engine_params,
    }
    json_all.append(json_object)
    
    parallel = row['parallel']

    if parallel == 1 or parallel == 100:
        json_1_or_100_thread.append(json_object)

format = '%Y-%M-%d' # T%H:%M:%S
now = datetime.now().replace(tzinfo=timezone.utc).strftime(format)

Path(f"results-{now}.json").write_text(json.dumps(json_all, indent=2))
Path(f"results-1-100-threads-{now}.json").write_text(json.dumps(json_1_or_100_thread, indent=2))

json_1_or_100_thread[-1], len(json_all), len(json_1_or_100_thread)
# Out:
# ({'engine_name': 'redis',
#   'setup_name': 'redis-m-32-ef-128',
#   'dataset_name': 'gist-960-euclidean',
#   'upload_time': 1968.1038949000067,
#   'total_upload_time': 1968.1039367000049,
#   'p95_time': 0.7069005783705506,
#   'rps': 153.90278313303938,
#   'parallel': 100,
#   'p99_time': 0.7310065932184807,
#   'mean_time': 0.6182948905912635,
#   'mean_precisions': 0.9488499999999999,
#   'engine_params': {'ef': 512,
#    'experiment': 'redis-m-32-ef-128',
#    'engine': 'redis',
#    'dataset': 'gist-960-euclidean',
#    'parallel': 16,
#    'hnsw_config': {'M': 32, 'EF_CONSTRUCTION': 128}}},
#  16,
#  16)
